# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv("spam.csv",encoding="ISO-8859-1")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
print (df['Unnamed: 2'].unique())
print (df['Unnamed: 2'].nunique())
# Out:
# [nan ' PO Box 5249'
#  ' the person is definitely special for u..... But if the person is so special'
#  ' HOWU DOIN? FOUNDURSELF A JOBYET SAUSAGE?LOVE JEN XXX\\""'
#  ' wanted to say hi. HI!!!\\" Stop? Send STOP to 62468"'
#  'this wont even start........ Datz confidence.."' 'GN' '.;-):-D"'
#  'just been in bedbut mite go 2 thepub l8tr if uwana mt up?loads a luv Jenxxx.\\""'
#  ' bt not his girlfrnd... G o o d n i g h t . . .@"' ' I\'ll come up"'
#  ' don\'t miss ur best life for anything... Gud nyt..."'
#  ' just as a shop has to give a guarantee on what they sell. B. G."'
#  ' But at d end my love compromised me for everything:-(\\".. Gud mornin:-)"'
#  ' the toughest is acting Happy with all unspoken pain inside..\\""'
#  ' smoke hella weed\\""' '\\" not \\"what i need to do.\\""'
#  'JUST GOT PAYED2DAY & I HAVBEEN GIVEN Aå£50 PAY RISE 4MY WORK & HAVEBEEN MADE PRESCHOOLCO-ORDINATOR 2I AM FEELINGOOD LUV\\""'
# ...

# %%
print(df['Unnamed: 3'].unique())
print(df['Unnamed: 3'].nunique())
# Out:
# [nan ' MK17 92H. 450Ppw 16"' ' why to miss them' 'GE'
#  'U NO THECD ISV.IMPORTANT TOME 4 2MORO\\""'
#  'i wil tolerat.bcs ur my someone..... But'
#  ' ILLSPEAK 2 U2MORO WEN IM NOT ASLEEP...\\""'
#  'whoever is the KING\\"!... Gud nyt"' ' TX 4 FONIN HON'
#  ' \\"OH No! COMPETITION\\". Who knew' 'IåÕL CALL U\\""']
# 10

# %%
print (df['Unnamed: 4'].unique())
print (df['Unnamed: 4'].nunique())
# Out:
# [nan ' just Keep-in-touch\\" gdeve.."' 'GNT:-)"'
#  ' Never comfort me with a lie\\" gud ni8 and sweet dreams"'
#  ' CALL 2MWEN IM BK FRMCLOUD 9! J X\\""'
#  ' one day these two will become FREINDS FOREVER!"']
# 5

# %%
print(df['v1'].unique())
print(df['v1'].nunique())
# Out:
# ['ham' 'spam']
# 2

# %%
# drop last 3 columns
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# renamming columns
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
## check missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (5169, 2)

# %%
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['target']=encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
import seaborn as sns

# %%
# Set custom labels for the x-axis

ax = sns.countplot(x='target', data=df)
ax.set_xticklabels(['ham', 'spam'])

# Display the plot
plt.show()
# Out:
# C:\Users\btirk\AppData\Local\Temp\ipykernel_16908\1474132827.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['ham', 'spam'])

# %%
import matplotlib.pyplot as plt 
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x213d9451fd0>,
# ...
#  [Text(-1.0144997251399075, 0.4251944351600247, 'ham'),
#   Text(1.014499764949479, -0.4251943401757036, 'spam')],
#  [Text(-0.5533634864399495, 0.23192423736001344, '87.37'),
#   Text(0.5533635081542612, -0.23192418555038377, '12.63')])

# %%
#conclusion imbalance data

# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to d:\pw live class resource\pw
# [nltk_data]     live project\spam project\spam
# [nltk_data]     classifier\venv\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to d:\pw live class
# [nltk_data]     resource\pw live project\spam project\spam
# [nltk_data]     classifier\venv\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['num_characters']=df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
# num of words
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
# num of setences
df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df.columns
# Out:
# Index(['target', 'text', 'num_characters', 'num_words', 'num_sentences'], dtype='object')

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
######these are ham (non spam messages)
df[df['target']==0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
######these are  ( spam messages)
df[df['target']==1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
########spam messeges avg is larger than ham messeges

sns.histplot(df[df['target']==0]['num_characters'])
sns.histplot(df[df['target']==1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df[['target','num_characters','num_words','num_sentences']].corr(),annot=True)
# Out:
# <Axes: >

# %%
"""Corpus	A collection of text used for NLP	example:Gutenberg corpus in NLTK
Stopwords	Common words removed from text	example:"is", "the", "in"
Stemming	Reducing words to their root form example:	"running" → "run", "flies" → "fli"
PorterStemmer	A popular stemming algorithm  example	"playing" → "play", "happiness" → "happi"
"""
# Out:
# 'Corpus\tA collection of text used for NLP\texample:Gutenberg corpus in NLTK\nStopwords\tCommon words removed from text\texample:"is", "the", "in"\nStemming\tReducing words to their root form example:\t"running" → "run", "flies" → "fli"\nPorterStemmer\tA popular stemming algorithm  example\t"playing" → "play", "happiness" → "happi"\n'

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to d:\pw live class
# [nltk_data]     resource\pw live project\spam project\spam
# [nltk_data]     classifier\venv\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import string

# %%
"""

transform_text function flow 

Converts to Lowercase:

Ensures uniformity by converting the entire text to lowercase.
Example: "Playing is Fun" → "playing is fun"
Tokenization (Splitting Words):

Uses NLTK’s word_tokenize to split text into individual words/tokens.
Example: "Hello! How are you?" → ['Hello', '!', 'How', 'are', 'you', '?']
Removes Non-Alphanumeric Characters:

Removes punctuation and special symbols, keeping only words and numbers.
Example: ['Hello', '!', 'How', 'are', 'you', '?'] → ['Hello', 'How', 'are', 'you']
Removes Stopwords & Punctuation:

Filters out common words like "is", "the", "and" (stopwords) and punctuation.
Example: ['Hello', 'How', 'are', 'you'] → ['Hello', 'How']
Applies Stemming Using PorterStemmer:

Converts words to their root form (removes suffixes like -ing, -ed, -es).
Example: ['playing', 'running', 'easily'] → ['play', 'run', 'easili']
Stores Intermediate Results in text = y[:]:

Creates a copy of y to prevent unwanted modifications.
y.clear() ensures y is empty before using it in the next step.
Joins Processed Words into Final Output String:

Uses " ".join(y) to return cleaned and transformed text.
Example Output: "play run easili"
"""
# Out:
# '\n\ntransform_text function flow \n\nConverts to Lowercase:\n\nEnsures uniformity by converting the entire text to lowercase.\nExample: "Playing is Fun" → "playing is fun"\nTokenization (Splitting Words):\n\nUses NLTK’s word_tokenize to split text into individual words/tokens.\nExample: "Hello! How are you?" → [\'Hello\', \'!\', \'How\', \'are\', \'you\', \'?\']\nRemoves Non-Alphanumeric Characters:\n\nRemoves punctuation and special symbols, keeping only words and numbers.\nExample: [\'Hello\', \'!\', \'How\', \'are\', \'you\', \'?\'] → [\'Hello\', \'How\', \'are\', \'you\']\nRemoves Stopwords & Punctuation:\n\nFilters out common words like "is", "the", "and" (stopwords) and punctuation.\nExample: [\'Hello\', \'How\', \'are\', \'you\'] → [\'Hello\', \'How\']\nApplies Stemming Using PorterStemmer:\n\nConverts words to their root form (removes suffixes like -ing, -ed, -es).\nExample: [\'playing\', \'running\', \'easily\'] → [\'play\', \'run\', \'easili\']\nStores Intermediate Results
# ...

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    
            
    return " ".join(y)

# %%
df['transformed_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
'''df[df['target'] == 1] → Filters spam messages.
['transformed_text'] → Selects the column with the processed text.
.str.cat(sep=" ") → Joins all spam messages into one large string, separating each message with a space.
'''

spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter

# %%
sns.barplot(x=pd.DataFrame(Counter(spam_corpus).most_common(30))[0], y=pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
"""df[df['target'] == 0] → Filters only ham messages (target == 0 means non-spam).
['transformed_text'] → Selects the column containing preprocessed (cleaned) text. 
 
 both line will give a series of line 
.tolist() → Converts the column into a Python list of messages.This will put all lines in a single list 
Outer Loop: Iterates through each ham message (msg).
Inner Loop: Splits each message line into words (msg.split())  and adds them to ham_corpus
"""

ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
"""Counter(ham_corpus) → Counts how many times each word appears.
.most_common(30) → Returns the 30 most frequent words as a list of (word, count) tuples.

pd.DataFrame(Counter(ham_corpus).most_common(30)) does the following :
It converts the list of tuples into a Pandas DataFrame.
The first column (index 0) contains the words.
The second column (index 1) contains the word frequencies.


x → Takes the first column (0), which contains the top 30 words.
y → Takes the second column (1), which contains the word counts.
"""


sns.barplot(x=pd.DataFrame(Counter(ham_corpus).most_common(30))[0], y=pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
'''The CountVectorizer and TfidfVectorizer are both tools from sklearn.feature_extraction.text 
that convert text data into numerical feature representations for machine learning models.

1. CountVectorizer()
It converts a collection of text documents into a matrix of token counts.
Each document is represented as a vector, where each entry corresponds to the frequency (count) of a word in the document.
It does not consider the importance of words across multiple documents, just their occurrence in individual documents.

2.TfidfVectorizer()
TfidfVectorizer stands for Term Frequency-Inverse Document Frequency (TF-IDF) Vectorizer.
Unlike CountVectorizer, it not only counts word occurrences but also assigns weights based on how important a word is in the entire dataset.
Words that appear frequently in all documents (e.g., "the", "is") get lower importance scores.
The max_features=3000 parameter limits the vocabulary to the top 3000 most important words (based on frequency and importance).

'''

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv=CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
X=tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df['target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# Dictionary of models
models = {
    "GaussianNB": GaussianNB(),
    "MultinomialNB": MultinomialNB(),
    "BernoulliNB": BernoulliNB(),
    "LogisticRegression": LogisticRegression(),
    "DecisionTree": DecisionTreeClassifier()
}

# %%
# Loop through each model
for name, model in models.items():
    model.fit(X_train, y_train)  # Train model
    y_pred = model.predict(X_test)  # Predict
    # Print results
    print(f"\nModel: {name}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(f"Precision: {precision_score(y_test, y_pred):.4f}")
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
# Out:
# Model: GaussianNB
# Accuracy: 0.8694
# Precision: 0.5068
# Confusion Matrix:
# [[788 108]
#  [ 27 111]]
#
# Model: MultinomialNB
# Accuracy: 0.9710
# Precision: 1.0000
# Confusion Matrix:
# [[896   0]
#  [ 30 108]]
#
# Model: BernoulliNB
# Accuracy: 0.9836
# Precision: 0.9919
# Confusion Matrix:
# [[895   1]
#  [ 16 122]]
#
# Model: LogisticRegression
# Accuracy: 0.9565
# Precision: 0.9794
# Confusion Matrix:
# [[894   2]
#  [ 43  95]]
#
# Model: DecisionTree
# Accuracy: 0.9429
# Precision: 0.7724
# Confusion Matrix:
# [[863  33]
#  [ 26 112]]

# %%
import pickle

# %%
mnb=MultinomialNB()

# %%
mnb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
pickle.dump(tfidf,open('vectorizer.pkl','wb')) #convert text to vector before  model creation so when user in frontend  give input the input will be 
                                               #in text we want that to be converted into vector before going to model that is why tfidf is dumped with 
                                               # model dump 
pickle.dump(mnb,open('model.pkl','wb'))
